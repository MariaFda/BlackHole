# %%
# %pylab inline
from scipy.special import erf
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
h=0.0005
n_points = int((1.0+h)/h)
t = zeros(n_points)
r = zeros(n_points)
v = zeros(n_points)
m = zeros(n_points)
m_dot = zeros(n_points)
rho = zeros(n_points)

# %%
t[0] = 0 
r[0] = 0.0
v[0] = 293.0
m[0] = 6.0E7
m_dot[0] = 0.0
rho= 1.0E6

# %%
G_GRAV = 4.9E-6 #unidades desconocidas
SIGMA = 97.0
LOG_LAMBDA = 10.0
RHO_STARS = 1.0E8
RHO_GAS = 1.0E6
C=11.0
EPSILON = 0.1
T_EDD = 44.0E-3 #Eddington time in Gyr
rc=G_GRAV*10*6/SIGMA
def func_r_prime(t, r, v):
    return v

def func_m_prime(t,r,v,m_bh):
    part_a = 4.0*pi*RHO_GAS*G_GRAV**2*(m_bh**2)
    part_b = (C**2 + v**2)**(3.0/2.0)
    eddington_rate = (m_bh/T_EDD)*(1.0-EPSILON)/EPSILON
    if part_a/part_b > eddington_rate:
        acc_rate = eddington_rate
    else:
        acc_rate = part_a/part_b
#    print "%e %e"%(eddington_rate, acc_rate)

    return acc_rate
    

def func_v_prime(t, r, v, m_bh, m_dot):
    part_a =  G_GRAV*(4.0*pi/3.0) * (RHO_STARS + RHO_GAS)* r

    part_b = 4.0*pi* (G_GRAV**2) * LOG_LAMBDA * RHO_STARS * m_bh / v**2
    ratio = abs(v/(sqrt(2.0) * SIGMA))
    part_c = erf(ratio) - 2.0*ratio*exp(-(ratio**2))/sqrt(pi)

    part_d = (abs(v)/m_bh)*m_dot

    return  -part_a - (part_b * part_c * v/abs(v)) - part_d

def func_rho_prime(t,r,v,m_bh,m_dot):
    part_a=RHO_GAS
    part_b=m_bh+m_dot
    part_c= 4/3*pi*rc**3
    
    
    return part_a-part_b /part_c

m_dot[0] = func_m_prime(t[0],r[0], v[0], m[0])
for i in range(1,n_points):
    #get the first derivatives
    r_prime = func_r_prime(t[i-1],r[i-1], v[i-1])
    m_prime = func_m_prime(t[i-1],r[i-1], v[i-1], m[i-1])
    v_prime = func_v_prime(t[i-1],r[i-1], v[i-1], m[i-1], m_prime)
    rho_prime = func_rho_prime(t[i-1],r[i-1], v[i-1], m[i-1])
    
    #from this estimation move to the middle point
    t_middle = t[i-1] + (h/2.0)
    r_middle = r[i-1] + (h/2.0) * r_prime
    v_middle = v[i-1] + (h/2.0) * v_prime 
    m_middle = m[i-1] + (h/2.0) * m_prime 
    rho_middle = rho[i-1] + (h/2.0) * rho_prime 
    #compute the derivatives at the middle point
    r_middle_prime = func_r_prime(t_middle, r_middle, v_middle)
    m_middle_prime = func_m_prime(t_middle, r_middle, v_middle, m_middle)
    v_middle_prime = func_v_prime(t_middle, r_middle, v_middle, m_middle, m_middle_prime)
    rho_middle_prime = func_rho_prime(t_middle, r_middle, v_middle, m_middle, m_middle_prime)
    
    t[i] = t[i-1] + h
    r[i] = r[i-1] + h * r_middle_prime 
    v[i] = v[i-1] + h * v_middle_prime
    m[i] = m[i-1] + h * m_middle_prime
    m_dot[i] = m_middle_prime
    rho[i] = rho[i-1] + h * rho_middle_prime
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e04ea71752b0> in <module>()
#      49     m_prime = func_m_prime(t[i-1],r[i-1], v[i-1], m[i-1])
#      50     v_prime = func_v_prime(t[i-1],r[i-1], v[i-1], m[i-1], m_prime)
# ---> 51     rho_prime = func_rho_prime(t[i-1],r[i-1], v[i-1], m[i-1])
#      52
#      53     #from this estimation move to the middle point
#
# TypeError: func_rho_prime() takes exactly 5 arguments (4 given)

# %%
print m[-1], m[0]
# Out:
# 918440994.921 60000000.0

# %%
plot(t,abs(r))
#Gráfica tiempo(giga-years) vs radio(kiloparsec)

# %%
plot(t,log10(m_dot))

# %%
plot(t, log10(m))
#Gráfica posición vs masa acretada

# %%
plot(r,rho)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a347674661d4> in <module>()
# ----> 1 plot(r,rho)
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2830         ax.hold(hold)
#    2831     try:
# -> 2832         ret = ax.plot(*args, **kwargs)
#    2833         draw_if_interactive()
#    2834     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    3994         lines = []
#    3995
# -> 3996         for line in self._get_lines(*args, **kwargs):
#    3997             self.add_line(line)
#    3998             lines.append(line)
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     328                 return
#     329             if len(remaining) <= 3:
# --> 330                 for seg in self._plot_args(remaining, kwargs):
# ...
